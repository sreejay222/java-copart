# %% [markdown]
# # Data Analysis
# ## Data description and Summarization

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inlin

# %% [markdown]
# hint, write any hint here for the above question.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/colaberry/data/master/Grad_Students/grad-students.csv')
df.head()
# Out:
#    Major_code                                   Major  \
# 0        5601                   CONSTRUCTION SERVICES
# 1        6004       COMMERCIAL ART AND GRAPHIC DESIGN
# 2        6211                  HOSPITALITY MANAGEMENT
# 3        2201  COSMETOLOGY SERVICES AND CULINARY ARTS
# 4        2001              COMMUNICATION TECHNOLOGIES
#
#                         Major_category  Grad_total  Grad_sample_size  \
# 0  Industrial Arts & Consumer Services        9173               200
# 1                                 Arts       53864               882
# 2                             Business       24417               437
# 3  Industrial Arts & Consumer Services        5411                72
# 4              Computers & Mathematics        9109               171
#
#    Grad_employed  Grad_full_time_year_round  Grad_unemployed  \
# 0           7098                       6511              681
# 1          40492                      29553             2482
# ...

# %%
## Plotting the graph for Major Categories and visualizing using Bar chart

# %% [markdown]
# # answer, write code which is a solution for above question.
# vc = df['Major_category'].value_counts()
# vc1=vc.plot(kind = 'bar')
# plt.show()

# %%
#this is assertion block which verifies the solution.
## Validating the Bar chart for Major Categories results. Declare the variable as vc

try:
    def verify_answer():
        
        #enter your verification code here.
        #return true if your checks pass
        #eg: 
        if vc[0] == 29: 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Visualizing the distribution of Graduated student in which Category declare the variable as Sum_Total

# %%
Sum_Total = df.groupby('Major_category')['Grad_total'].sum()
Sum_Total.plot(kind = 'bar')
plt.show()
# Out:
# 241342

# %%
## Validating the Bar chart for Graduates in total results.

# %% [markdown]
# #this is assertion block which verifies the solution.
#
# try:
#     def verify_answer():
#
#         if Sum_Total[0] == 241342 :
#             return True
#         else:
#             return False
#
#     ref_assert_var = verify_answer()
# except Exception as e:
#     print('Your assertion block throws error: ' + str(e))
# else:
#     if ref_assert_var:
#         print('continue')
#     else:
#         print('The answer did not pass the test.')

# %%
# Variable Relationship Identification and Comparison
### Checking the overall correlation from given data by including all the possible continues variables
### Correlation

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# %%
### Validating the Correlation value. declare the variable as corr

# %%
try:
    def verify_answer():
        
        #enter your verification code here.
        #return true if your checks pass
        #eg: 
        if round(corr['Major_code'][1],4) == 0.0955: 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Linear Regression Begins
# ### Our Dataset doesn't have predicting column hence we need to create the predicting variable
# ## Example
# ### column Grad_unemployment_rate is given hence we can fetch Grad_employment_rate from 1.
# ### for instance Grad_unemployment_rate = 0.08754
# ### hence Grad_employment_rate = 1-0.08754 = 0.91246
# ### Declare the variable name as Grad_employment_rate

# %%
### Creating column for Graduate employment rate
df['Grad_employment_rate'] = 1-df['Grad_unemployment_rate']

# %%
try:
    def verify_answer():
        
        #enter your verification code here.
        #return true if your checks pass
        #eg: 
        if round(df['Grad_employment_rate'][0],3) == 0.912: 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %%
### picking up 4 independent variable to check from above correlation which are not highly co-related
X = df[['Grad_total','Grad_median','Grad_share','Grad_premium','Nongrad_unemployment_rate']]
## Assinging Grad_employment_rate as Y since it is the predicting variable
y = df[['Grad_employment_rate']]

# %%
## Pairplot on independent variable to see the distribution of the data and whether they are normally distributed or not.
sns.pairplot(X)

# %% [markdown]
# # Data Training and Validation

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [[  7.26760436e-09  -8.18587627e-08   3.92860349e-02   1.69333830e-02
#    -1.58380172e-01]]

# %%
try:
    def verify_answer():
        
        #enter your verification code here.
        #return true if your checks pass
        #eg: 
        if X_train['Grad_total'][0] == 9173: 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %%
# Forecasting Output

# %%
#fit = np.polyfit(y_test, predictions, deg=1)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions,color = ['red','blue'])
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %% [markdown]
# try:
#     def verify_answer():
#
#         #enter your verification code here.
#         #return true if your checks pass
#         #eg:
#         if 1== 1:
#             return True
#         else:
#             return False
#
#
#     ref_assert_var = verify_answer()
# except Exception as e:
#     print('Your assertion block throws error: ' + str(e))
# else:
#     if ref_assert_var:
#         print('continue')
#     else:
#         print('The answer did not pass the test.')

# %%
# calculate these metrics by hand!
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.0104617566264
# MSE: 0.000188005579614
# RMSE: 0.0137115126669

# %%
try:
    def verify_answer():
        
        #enter your verification code here.
        #return true if your checks pass
        #eg: 
        if round(metrics.mean_absolute_error(y_test, predictions),2)== 0.01: 
            return True
        else:
            return False
        

    ref_assert_var = verify_answer()
except Exception as e:
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %%
## Distribution of variations
sns.distplot((y_test-predictions),bins=50);
